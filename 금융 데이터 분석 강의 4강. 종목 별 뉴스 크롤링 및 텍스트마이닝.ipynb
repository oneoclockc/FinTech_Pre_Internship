# %% [markdown]
# # pd.read_html() 실습

# %% [markdown]
# pd.read_html은 웹 페이지로부터 테이블을 추출하여 데이터프레임으로 저장하는 코드이다.
# - pd.read_html('테이블이 존재하는 URL')

# %% [markdown]
# http://m.infostock.co.kr/sector/sector.asp?mode=w

# %% [markdown]
# : 테마와 해당 테마들에 대한 종목을 알려주는 사이트이다.

# %% [markdown]
# http://m.infostock.co.kr/sector/sector_detail.asp?code=64&theme=2%uCC28%uC804%uC9C0&mode=w

# %% [markdown]
# 2차 전지 테마주

# %%
import pandas as pd
pd.read_html('http://m.infostock.co.kr/sector/sector_detail.asp?code=64&theme=2%uCC28%uC804%uC9C0&mode=w')
# Out:
# [    0   1   2     3   4
#  0 NaN NaN NaN  회원가입 NaN,
#                    0                                                  1
#  0               테마명                                               2차전지
#  1              테마개요  2차전지(Secondary battery)란 한 번 쓰고 버리는 배터리가 아닌 재충...
#  2           테마 히스토리  (2021-07-23) 벤츠, 2030년까지 전동화 전환에 약 54조원 투자 계획 ...
#  3              관련종목                                             테마편입사유
#  4   - LG화학 (051910)  LG그룹 계열의 국내 대표적인 화학기업. 전지사업부문(자동차전지, ESS전지, 소형...
#  ..              ...                                                ...
#  82   - 엔시스 (333620)  2차전지 배터리 생산 공정별 머신비전검사장비 전문 업체. 2차전지 배터리 생산 전극...
#  83  - 에스코넥 (096630)            삼성SDI의 1차벤더로 2차전지 소형전지부품인 CID를 생산 및 납품.
#  84  - DI동일 (001530)      종속회사 동일알루미늄, 2차전지용 알루미늄박을 생산하여 국내 배터리 3사에 공급.
#  85   - 이녹스 (088390)        2차전지 음극재용 원소재 제조 사업을 영위중인 티알에스를 종속회사로 보유중임.
#  86  - 고려아연 (010130)  20년3월 2차전지용 전해동박 사업 진출을 위해 자회사 케이잼주식회사(KZAM Co...
#
#  [87 rows x 2 columns]]

# %%
len(pd.read_html('http://m.infostock.co.kr/sector/sector_detail.asp?code=64&theme=2%uCC28%uC804%uC9C0&mode=w'))
# read.html 은 테이블의 리스트를 반환하므로 len을 통해 개수를 구해야 함
# Out:
# 2

# %%
pd.read_html('http://m.infostock.co.kr/sector/sector_detail.asp?code=64&theme=2%uCC28%uC804%uC9C0&mode=w')[0]
# Out:
#     0   1   2     3   4
# 0 NaN NaN NaN  회원가입 NaN

# %%
pd.read_html('http://m.infostock.co.kr/sector/sector_detail.asp?code=64&theme=2%uCC28%uC804%uC9C0&mode=w')[1]
# Out:
#                   0                                                  1
# 0               테마명                                               2차전지
# 1              테마개요  2차전지(Secondary battery)란 한 번 쓰고 버리는 배터리가 아닌 재충...
# 2           테마 히스토리  (2021-07-23) 벤츠, 2030년까지 전동화 전환에 약 54조원 투자 계획 ...
# 3              관련종목                                             테마편입사유
# 4   - LG화학 (051910)  LG그룹 계열의 국내 대표적인 화학기업. 전지사업부문(자동차전지, ESS전지, 소형...
# ..              ...                                                ...
# 82   - 엔시스 (333620)  2차전지 배터리 생산 공정별 머신비전검사장비 전문 업체. 2차전지 배터리 생산 전극...
# 83  - 에스코넥 (096630)            삼성SDI의 1차벤더로 2차전지 소형전지부품인 CID를 생산 및 납품.
# 84  - DI동일 (001530)      종속회사 동일알루미늄, 2차전지용 알루미늄박을 생산하여 국내 배터리 3사에 공급.
# 85   - 이녹스 (088390)        2차전지 음극재용 원소재 제조 사업을 영위중인 티알에스를 종속회사로 보유중임.
# 86  - 고려아연 (010130)  20년3월 2차전지용 전해동박 사업 진출을 위해 자회사 케이잼주식회사(KZAM Co...
#
# [87 rows x 2 columns]

# %%
df = pd.read_html('http://m.infostock.co.kr/sector/sector_detail.asp?code=64&theme=2%uCC28%uC804%uC9C0&mode=w')[1]
df = df[3:]
df
# Out:
#                      0                                                  1
# 3                 관련종목                                             테마편입사유
# 4      - LG화학 (051910)  LG그룹 계열의 국내 대표적인 화학기업. 전지사업부문(자동차전지, ESS전지, 소형...
# 5     - 삼성SDI (006400)  소형전지(휴대폰, 태블릿PC, 전기자전거 용), 자동차전지(하이브리드카, 전기차 용...
# 6   - SK이노베이션 (096770)  SK그룹 계열의 종합에너지기업. 배터리 사업을 영위중. 친환경 전기자동차 및 ESS...
# 7      - 에코프로 (086520)   양극활물질 등 2차전지 사업을 분할하여 에코프로비엠을 신규 설립한 뒤 종속회사로 보유.
# ..                 ...                                                ...
# 82      - 엔시스 (333620)  2차전지 배터리 생산 공정별 머신비전검사장비 전문 업체. 2차전지 배터리 생산 전극...
# 83     - 에스코넥 (096630)            삼성SDI의 1차벤더로 2차전지 소형전지부품인 CID를 생산 및 납품.
# 84     - DI동일 (001530)      종속회사 동일알루미늄, 2차전지용 알루미늄박을 생산하여 국내 배터리 3사에 공급.
# 85      - 이녹스 (088390)        2차전지 음극재용 원소재 제조 사업을 영위중인 티알에스를 종속회사로 보유중임.
# 86     - 고려아연 (010130)  20년3월 2차전지용 전해동박 사업 진출을 위해 자회사 케이잼주식회사(KZAM Co...
#
# [84 rows x 2 columns]

# %%
df.iloc[0] # 0번 행 추출
# Out:
# 0      관련종목
# 1    테마편입사유
# Name: 3, dtype: object

# %%
df.iloc[0].to_list()
# Out:
# ['관련종목', '테마편입사유']

# %%
df.columns = df.iloc[0].to_list()
df
# Out:
#                   관련종목                                             테마편입사유
# 3                 관련종목                                             테마편입사유
# 4      - LG화학 (051910)  LG그룹 계열의 국내 대표적인 화학기업. 전지사업부문(자동차전지, ESS전지, 소형...
# 5     - 삼성SDI (006400)  소형전지(휴대폰, 태블릿PC, 전기자전거 용), 자동차전지(하이브리드카, 전기차 용...
# 6   - SK이노베이션 (096770)  SK그룹 계열의 종합에너지기업. 배터리 사업을 영위중. 친환경 전기자동차 및 ESS...
# 7      - 에코프로 (086520)   양극활물질 등 2차전지 사업을 분할하여 에코프로비엠을 신규 설립한 뒤 종속회사로 보유.
# ..                 ...                                                ...
# 82      - 엔시스 (333620)  2차전지 배터리 생산 공정별 머신비전검사장비 전문 업체. 2차전지 배터리 생산 전극...
# 83     - 에스코넥 (096630)            삼성SDI의 1차벤더로 2차전지 소형전지부품인 CID를 생산 및 납품.
# 84     - DI동일 (001530)      종속회사 동일알루미늄, 2차전지용 알루미늄박을 생산하여 국내 배터리 3사에 공급.
# 85      - 이녹스 (088390)        2차전지 음극재용 원소재 제조 사업을 영위중인 티알에스를 종속회사로 보유중임.
# 86     - 고려아연 (010130)  20년3월 2차전지용 전해동박 사업 진출을 위해 자회사 케이잼주식회사(KZAM Co...
#
# [84 rows x 2 columns]

# %%
df = df[1:]
df
# Out:
#                   관련종목                                             테마편입사유
# 4      - LG화학 (051910)  LG그룹 계열의 국내 대표적인 화학기업. 전지사업부문(자동차전지, ESS전지, 소형...
# 5     - 삼성SDI (006400)  소형전지(휴대폰, 태블릿PC, 전기자전거 용), 자동차전지(하이브리드카, 전기차 용...
# 6   - SK이노베이션 (096770)  SK그룹 계열의 종합에너지기업. 배터리 사업을 영위중. 친환경 전기자동차 및 ESS...
# 7      - 에코프로 (086520)   양극활물질 등 2차전지 사업을 분할하여 에코프로비엠을 신규 설립한 뒤 종속회사로 보유.
# 8       - 피엔티 (137400)  롤투롤(Roll-to-Roll) 기술을 활용한 디스플레이 및 2차전지 소재 생산장비...
# ..                 ...                                                ...
# 82      - 엔시스 (333620)  2차전지 배터리 생산 공정별 머신비전검사장비 전문 업체. 2차전지 배터리 생산 전극...
# 83     - 에스코넥 (096630)            삼성SDI의 1차벤더로 2차전지 소형전지부품인 CID를 생산 및 납품.
# 84     - DI동일 (001530)      종속회사 동일알루미늄, 2차전지용 알루미늄박을 생산하여 국내 배터리 3사에 공급.
# 85      - 이녹스 (088390)        2차전지 음극재용 원소재 제조 사업을 영위중인 티알에스를 종속회사로 보유중임.
# 86     - 고려아연 (010130)  20년3월 2차전지용 전해동박 사업 진출을 위해 자회사 케이잼주식회사(KZAM Co...
#
# [83 rows x 2 columns]

# %%
df = df.reset_index(drop=True) # drop() : 인덱스로 세팅한 열을 남겨놓을지
df
# Out:
#                   관련종목                                             테마편입사유
# 0      - LG화학 (051910)  LG그룹 계열의 국내 대표적인 화학기업. 전지사업부문(자동차전지, ESS전지, 소형...
# 1     - 삼성SDI (006400)  소형전지(휴대폰, 태블릿PC, 전기자전거 용), 자동차전지(하이브리드카, 전기차 용...
# 2   - SK이노베이션 (096770)  SK그룹 계열의 종합에너지기업. 배터리 사업을 영위중. 친환경 전기자동차 및 ESS...
# 3      - 에코프로 (086520)   양극활물질 등 2차전지 사업을 분할하여 에코프로비엠을 신규 설립한 뒤 종속회사로 보유.
# 4       - 피엔티 (137400)  롤투롤(Roll-to-Roll) 기술을 활용한 디스플레이 및 2차전지 소재 생산장비...
# ..                 ...                                                ...
# 78      - 엔시스 (333620)  2차전지 배터리 생산 공정별 머신비전검사장비 전문 업체. 2차전지 배터리 생산 전극...
# 79     - 에스코넥 (096630)            삼성SDI의 1차벤더로 2차전지 소형전지부품인 CID를 생산 및 납품.
# 80     - DI동일 (001530)      종속회사 동일알루미늄, 2차전지용 알루미늄박을 생산하여 국내 배터리 3사에 공급.
# 81      - 이녹스 (088390)        2차전지 음극재용 원소재 제조 사업을 영위중인 티알에스를 종속회사로 보유중임.
# 82     - 고려아연 (010130)  20년3월 2차전지용 전해동박 사업 진출을 위해 자회사 케이잼주식회사(KZAM Co...
#
# [83 rows x 2 columns]

# %% [markdown]
# # 회사명과 종목 코드 얻기

# %%
import pandas as pd

# %%
dfstockcode = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download', header=0)[0]

# %%
dfstockcode
# Out:
#             회사명    종목코드               업종  \
# 0         DRB동일    4840         고무제품 제조업
# 1           DSR  155660      1차 비철금속 제조업
# 2         GS글로벌    1250        상품 종합 도매업
# 3     HDC현대산업개발  294870           건물 건설업
# 4           KEC   92220          반도체 제조업
# ...         ...     ...              ...
# 2445       타임기술  318660   소프트웨어 개발 및 공급업
# 2446         툴젠  199800  자연과학 및 공학 연구개발업
# 2447   플럼라인생명과학  222670  자연과학 및 공학 연구개발업
# 2448   한국미라클피플사  331660      기타 화학제품 제조업
# 2449        휴벡셀  212310       의료용 기기 제조업
#
#                                                    주요제품         상장일  결산월  \
# 0                     고무벨트(V벨트,콘베이어벨트,평벨트),프라스틱제품 제조,판매  1976-05-21  12월
# 1                                                합섬섬유로프  2013-05-15  12월
# 2     수출입업(시멘트,철강금속,전기전자,섬유,기계화학),상품중개,광업,채석업/하수처리 서...  1976-06-26  12월
# 3                                외주주택, 자체공사, 일반건축, 토목 등  2018-06-12  12월
# 4                                                반도체 제조  2006-10-16  12월
# ...

# %% [markdown]
# 데이터 분석을 할 때는 반드시 info()와 isnull().sum()을 통해서 각 열의 타입이 무엇인지, 결측값은 없는지 습관적으로 확인하기!!

# %%
dfstockcode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2450 entries, 0 to 2449
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사명     2450 non-null   object
#  1   종목코드    2450 non-null   int64
#  2   업종      2450 non-null   object
#  3   주요제품    2431 non-null   object
#  4   상장일     2450 non-null   object
#  5   결산월     2450 non-null   object
#  6   대표자명    2450 non-null   object
#  7   홈페이지    2270 non-null   object
#  8   지역      2450 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 172.4+ KB

# %%
dfstockcode.isnull().sum()
# Out:
# 회사명       0
# 종목코드      0
# 업종        0
# 주요제품     19
# 상장일       0
# 결산월       0
# 대표자명      0
# 홈페이지    180
# 지역        0
# dtype: int64

# %%
dfstockcode.종목코드 = dfstockcode.종목코드.map('{:06d}'.format)

# %%
dfstockcode
# Out:
#             회사명    종목코드               업종  \
# 0         DRB동일  004840         고무제품 제조업
# 1           DSR  155660      1차 비철금속 제조업
# 2         GS글로벌  001250        상품 종합 도매업
# 3     HDC현대산업개발  294870           건물 건설업
# 4           KEC  092220          반도체 제조업
# ...         ...     ...              ...
# 2445       타임기술  318660   소프트웨어 개발 및 공급업
# 2446         툴젠  199800  자연과학 및 공학 연구개발업
# 2447   플럼라인생명과학  222670  자연과학 및 공학 연구개발업
# 2448   한국미라클피플사  331660      기타 화학제품 제조업
# 2449        휴벡셀  212310       의료용 기기 제조업
#
#                                                    주요제품         상장일  결산월  \
# 0                     고무벨트(V벨트,콘베이어벨트,평벨트),프라스틱제품 제조,판매  1976-05-21  12월
# 1                                                합섬섬유로프  2013-05-15  12월
# 2     수출입업(시멘트,철강금속,전기전자,섬유,기계화학),상품중개,광업,채석업/하수처리 서...  1976-06-26  12월
# 3                                외주주택, 자체공사, 일반건축, 토목 등  2018-06-12  12월
# 4                                                반도체 제조  2006-10-16  12월
# ...

# %%
dfstockcode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2450 entries, 0 to 2449
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사명     2450 non-null   object
#  1   종목코드    2450 non-null   object
#  2   업종      2450 non-null   object
#  3   주요제품    2431 non-null   object
#  4   상장일     2450 non-null   object
#  5   결산월     2450 non-null   object
#  6   대표자명    2450 non-null   object
#  7   홈페이지    2270 non-null   object
#  8   지역      2450 non-null   object
# dtypes: object(9)
# memory usage: 172.4+ KB

# %%
stock_to_code = dict(zip(dfstockcode.회사명, dfstockcode.종목코드))

# %%
stock_to_code['삼성전자']
# Out:
# '005930'

# %% [markdown]
# # 종목별 뉴스 크롤링

# %% [markdown]
# https://finance.naver.com/item/news_news.nhn?code=005930&page=10

# %% [markdown]
# 특정 종목의 뉴스에 접근하는 url
# - code= 종목번호
# - page= 페이지 번호

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import os

# %%
url = 'https://finance.naver.com/item/news_news.nhn?code=005930&page=10'
source_code = requests.get(url).text

# %%
source_code
# Out:
# '<html lang="ko">\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=euc-kr">\n<title>네이버 금융</title>\n\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/newstock.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/common.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/layout.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/main.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/newstock2.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/newstock3.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/world.css">\n</head>\n<body>\n<script
# ...

# %%
html = BeautifulSoup(source_code, "html.parser")

# %%
html
# Out:
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>네이버 금융</title>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/newstock.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/layout.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/main.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/newstock2.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/newstock3.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20210721200146/css/world.css" rel="stylesheet" type="text/css"/>
# </head>
# ...

# %% [markdown]
# 뉴스 기사는 일반적으로 <td class="title"> </td> 라는 태그 안에 있음

# %%
titles = html.select('.title')
print(titles)
# Out:
# [<td class="title">
# <a class="tit" href="/item/news_read.nhn?article_id=0004989597&amp;office_id=018&amp;code=005930&amp;page=10&amp;sm=" onclick="clickcr(this,'stn.ntitclust','','',event);" target="_top">“화면 내구성 높여라”…삼성 ‘갤럭시Z 폴드3’ 업그레이드 UTG 탑재</a>
# </td>, <td class="title">
# <a class="tit" href="/item/news_read.nhn?article_id=0004618811&amp;office_id=008&amp;code=005930&amp;page=10&amp;sm=" onclick="clickcr(this,'stn.ntitclust','','',event);" target="_top">삼성전자 개미들 곡소리…'연중 최저가' 또 찍었다</a>
# </td>, <td class="title">
# <a class="tit" href="/item/news_read.nhn?article_id=0004826457&amp;office_id=009&amp;code=005930&amp;page=10&amp;sm=" onclick="clickcr(this,'stn.ntitclust','','',event);" target="_top">델타 변이 금융시장도 덮쳤다…증시 코인 유가 급락, 삼성전자 연중 최저...</a>
# </td>, <td class="title">
# ...

# %%
len(titles)
# Out:
# 10

# %%
titles[0]
# Out:
# <td class="title">
# <a class="tit" href="/item/news_read.nhn?article_id=0004989597&amp;office_id=018&amp;code=005930&amp;page=10&amp;sm=" onclick="clickcr(this,'stn.ntitclust','','',event);" target="_top">“화면 내구성 높여라”…삼성 ‘갤럭시Z 폴드3’ 업그레이드 UTG 탑재</a>
# </td>

# %%
type(titles[0])
# Out:
# bs4.element.Tag

# %%
titles[0].get_text()
# Out:
# '\n“화면 내구성 높여라”…삼성 ‘갤럭시Z 폴드3’ 업그레이드 UTG 탑재\n'

# %%
# 제목 추출하기
result=[]

for title in titles: 
  title = title.get_text() 
  # 줄바꿈 문자를 의미하는 '\n'가 거슬리므로 제거해줍니다.
  title = re.sub('\n','',title)
  result.append(title)

# %%
result[:3]
# Out:
# ['“화면 내구성 높여라”…삼성 ‘갤럭시Z 폴드3’ 업그레이드 UTG 탑재',
#  "삼성전자 개미들 곡소리…'연중 최저가' 또 찍었다",
#  '델타 변이 금융시장도 덮쳤다…증시 코인 유가 급락, 삼성전자 연중 최저...']

# %%
len(result)
# Out:
# 10

# %%
titles[0]
# Out:
# <td class="title">
# <a class="tit" href="/item/news_read.nhn?article_id=0004989597&amp;office_id=018&amp;code=005930&amp;page=10&amp;sm=" onclick="clickcr(this,'stn.ntitclust','','',event);" target="_top">“화면 내구성 높여라”…삼성 ‘갤럭시Z 폴드3’ 업그레이드 UTG 탑재</a>
# </td>

# %% [markdown]
# <태그명 속성명="속성값"> 형태의 태그가 있을 때 해당 태그로부터 속성값을 추출하기 위해
# find('태그명')['속성명'] 을 사용한다.

# %%
tag = "<p class='youngone' id='junu'> Hello World! </p>"
soup = BeautifulSoup(tag,  "html.parser")

print(soup.find('p')['id']) # p 태그의 id 속성의 속성값
# Out:
# junu

# %%
# 링크 추출하기
result = []

for title in titles: 
  add = 'https://finance.naver.com' + title.find('a')['href']
  result.append(add)

# %%
len(result)
# Out:
# 10

# %%
result[:3]
# Out:
# ['https://finance.naver.com/item/news_read.nhn?article_id=0004989597&office_id=018&code=005930&page=10&sm=',
#  'https://finance.naver.com/item/news_read.nhn?article_id=0004618811&office_id=008&code=005930&page=10&sm=',
#  'https://finance.naver.com/item/news_read.nhn?article_id=0004826457&office_id=009&code=005930&page=10&sm=']

# %%
def crawler(company_name, maxpage):
    df_result = None
    page = 1 
    company_code = stock_to_code[company_name]
    
    # 1페이지부터 maxpage의 페이지까지
    while page <= int(maxpage): 
    
        url = 'https://finance.naver.com/item/news_news.nhn?code=' + str(company_code) + '&page=' + str(page) 
        source_code = requests.get(url).text
        html = BeautifulSoup(source_code, "lxml") 
 
# 뉴스 제목 
        titles = html.select('.title')
        title_result=[]
        for title in titles: 
            title = title.get_text() 
            title = re.sub('\n','',title)
            title_result.append(title)
 
# 뉴스 링크
        links = html.select('.title') 
 
        link_result =[]
        for link in links: 
            add = 'https://finance.naver.com' + link.find('a')['href']
            link_result.append(add)
 

        # 변수들 합쳐서 해당 디렉토리에 csv파일로 저장하기 
        result= {"기사제목" : title_result, "링크" : link_result} 
        df_temp = pd.DataFrame(result)
        
        if df_result is not None:
        # for문 내에서 데이터프레임이 새로 만들어질 때마다
        # 이전 데이터프레임과 지속적으로 결합
          df_result = pd.concat([df_result, df_temp])
        else:
          df_result = df_temp
        
        print(page,"페이지 진행 중입니다.")
 
        page += 1
    return df_result

# %%
df_result = crawler('삼성전자', 10)
df_result
# Out:
# 1 페이지 진행 중입니다.
# 2 페이지 진행 중입니다.
# 3 페이지 진행 중입니다.
# 4 페이지 진행 중입니다.
# 5 페이지 진행 중입니다.
# 6 페이지 진행 중입니다.
# 7 페이지 진행 중입니다.
# 8 페이지 진행 중입니다.
# 9 페이지 진행 중입니다.
# 10 페이지 진행 중입니다.
#                                           기사제목  \
# 0        삼성전자 "도쿄올림픽서 캐나다가 메달 딸 때마다 1000달러 기부"
# 1             삼성전자 "캐나다 선수 메달 딸 때마다 1000달러 기부"
# 2            삼성전자, 캐나다 선수가 메달 딸 때마다 1,000달러 기부
# 3         삼성전자, 도쿄올림픽서 캐나다가 메달 딸 때마다 1000달러 기부
# 4               반도체 ETF에 삼성전자가 빠졌다고? 수익률은 '쏠쏠'
# ..                                         ...
# 5   삼성만 때리는 공정위?…"급식 몰아줬다" 2349억원 과징금, 법원 결...
# 6       삼성전자 "실패 걱정없이 연구를"…AI·암호시스템 등 국가기술 키운다
# 7                 애플 샤오미 다 비켜…삼성 스마트폰 1위 칼 갈았다
# 8          '갤폴드3' 가격 낮춘 삼성전자..'폴더블폰 대중화' 본격 시동
# 9               역시 삼성전자, 국내 최대 사회복지사업 450억원 규모
#
#                                                    링크
# 0   https://finance.naver.com/item/news_read.nhn?a...
# 1   https://finance.naver.com/item/news_read.nhn?a...
# 2   https://finance.naver.com/item/news_read.nhn?a...
# ...

# %% [markdown]
# # 본문 추출하기

# %% [markdown]
# newspaper3k는 뉴스 데이터를 크롤링을 위한 패키지이다. 사용자가 인터넷 뉴스 기사의 url을 전달해주면, 이로부터 뉴스 기사의 제목과 텍스트를 추출한다.

# %%
df_result.iloc[0]['링크']
# Out:
# 'https://finance.naver.com/item/news_read.nhn?article_id=0004943022&office_id=277&code=005930&page=1&sm='

# %%
from newspaper import Article

# 파싱할 뉴스 기사 주소
url = 'https://finance.naver.com/item/news_read.nhn?article_id=0004960169&office_id=018&code=005930&page=10&sm='

# 언어가 한국어이므로 language='ko'로 설정
article = Article(url, language='ko')
article.download()
article.parse()

# %%
# 기사 내용 출력
print('기사 내용 :')
print(article.text)
# Out:
# 기사 내용 :
# 사진=연합뉴스
#
# 자료=한은
#
# ...

# %%
def url_to_text(url):
  article = Article(url, language='ko')
  article.download()
  article.parse()
  return article.text

# %%
# 데이터프레임['새로운열'] = 데이터프레임['열이름'].apply(함수)
# 해당 데이터프레임의 열이름의 열에다가 전체 행에 해당 함수를 적용하여 새로운 열에다가 저장해라

# %%
df_result['본문'] = df_result['링크'].apply(url_to_text)

# %%
df_result
# Out:
#                                           기사제목  \
# 0        삼성전자 "도쿄올림픽서 캐나다가 메달 딸 때마다 1000달러 기부"
# 1             삼성전자 "캐나다 선수 메달 딸 때마다 1000달러 기부"
# 2            삼성전자, 캐나다 선수가 메달 딸 때마다 1,000달러 기부
# 3         삼성전자, 도쿄올림픽서 캐나다가 메달 딸 때마다 1000달러 기부
# 4               반도체 ETF에 삼성전자가 빠졌다고? 수익률은 '쏠쏠'
# ..                                         ...
# 5   삼성만 때리는 공정위?…"급식 몰아줬다" 2349억원 과징금, 법원 결...
# 6       삼성전자 "실패 걱정없이 연구를"…AI·암호시스템 등 국가기술 키운다
# 7                 애플 샤오미 다 비켜…삼성 스마트폰 1위 칼 갈았다
# 8          '갤폴드3' 가격 낮춘 삼성전자..'폴더블폰 대중화' 본격 시동
# 9               역시 삼성전자, 국내 최대 사회복지사업 450억원 규모
#
#                                                    링크  \
# 0   https://finance.naver.com/item/news_read.nhn?a...
# 1   https://finance.naver.com/item/news_read.nhn?a...
# 2   https://finance.naver.com/item/news_read.nhn?a...
# 3   https://finance.naver.com/item/news_read.nhn?a...
# 4   https://finance.naver.com/item/news_read.nhn?a...
# ..                                                ...
# ...

# %%
df_result.to_csv('삼성전자 뉴스.csv', index=False, encoding='utf-8-sig')

# %%
loaded_df = pd.read_csv('삼성전자 뉴스.csv')

# %%
loaded_df
# Out:
#                                            기사제목  \
# 0         삼성전자 "도쿄올림픽서 캐나다가 메달 딸 때마다 1000달러 기부"
# 1              삼성전자 "캐나다 선수 메달 딸 때마다 1000달러 기부"
# 2             삼성전자, 캐나다 선수가 메달 딸 때마다 1,000달러 기부
# 3          삼성전자, 도쿄올림픽서 캐나다가 메달 딸 때마다 1000달러 기부
# 4                반도체 ETF에 삼성전자가 빠졌다고? 수익률은 '쏠쏠'
# ..                                          ...
# 145  삼성만 때리는 공정위?…"급식 몰아줬다" 2349억원 과징금, 법원 결...
# 146      삼성전자 "실패 걱정없이 연구를"…AI·암호시스템 등 국가기술 키운다
# 147                애플 샤오미 다 비켜…삼성 스마트폰 1위 칼 갈았다
# 148         '갤폴드3' 가격 낮춘 삼성전자..'폴더블폰 대중화' 본격 시동
# 149              역시 삼성전자, 국내 최대 사회복지사업 450억원 규모
#
#                                                     링크  \
# 0    https://finance.naver.com/item/news_read.nhn?a...
# 1    https://finance.naver.com/item/news_read.nhn?a...
# 2    https://finance.naver.com/item/news_read.nhn?a...
# 3    https://finance.naver.com/item/news_read.nhn?a...
# 4    https://finance.naver.com/item/news_read.nhn?a...
# ...

# %% [markdown]
# # 명사 추출

# %%
from konlpy.tag import Okt # 형태소 분석을 위한 패키지 설치

# %%
tokenizer = Okt()

# %%
kor_text = '밤에 귀가하던 여성에게 범죄를 시도한 대 남성이 구속됐다서울 제주경찰서는 \
            상해 혐의로 씨를 구속해 수사하고 있다고 일 밝혔다씨는 지난달 일 피해 여성을 \
            인근 지하철 역에서부터 따라가 폭행을 시도하려다가 도망간 혐의를 받는다피해 \
            여성이 저항하자 놀란 씨는 도망갔으며 신고를 받고 주변을 수색하던 경찰에 \
            체포됐다피해 여성은 이 과정에서 경미한 부상을 입은 것으로 전해졌다'

# 문장에서 명사만 추출 (100% 정확하진 않아요!)
print(tokenizer.nouns(kor_text))
# Out:
# ['밤', '귀가', '여성', '범죄', '시도', '남성', '구속', '서울', '경찰서', '상해', '혐의', '씨', '구속', '수사', '일', '씨', '지난달', '일', '피해', '여성', '인근', '지하철', '역', '폭행', '시도', '혐의', '피해', '여성', '저항', '놀란', '씨', '신고', '주변', '수색', '경찰', '체포', '피해', '여성', '이', '과정', '부상', '것']

# %% [markdown]
# 데이터프레임이름['열의 이름'].apply(동작 코드)
#
# -> 각 코드를 데이터프레임의 특정 열(column. 즉, 세로 방향) 전체에 적용

# %%
loaded_df['tokenized'] = loaded_df['본문'].apply(tokenizer.nouns)

# %%
loaded_df
# Out:
#                                            기사제목  \
# 0         삼성전자 "도쿄올림픽서 캐나다가 메달 딸 때마다 1000달러 기부"
# 1              삼성전자 "캐나다 선수 메달 딸 때마다 1000달러 기부"
# 2             삼성전자, 캐나다 선수가 메달 딸 때마다 1,000달러 기부
# 3          삼성전자, 도쿄올림픽서 캐나다가 메달 딸 때마다 1000달러 기부
# 4                반도체 ETF에 삼성전자가 빠졌다고? 수익률은 '쏠쏠'
# ..                                          ...
# 145  삼성만 때리는 공정위?…"급식 몰아줬다" 2349억원 과징금, 법원 결...
# 146      삼성전자 "실패 걱정없이 연구를"…AI·암호시스템 등 국가기술 키운다
# 147                애플 샤오미 다 비켜…삼성 스마트폰 1위 칼 갈았다
# 148         '갤폴드3' 가격 낮춘 삼성전자..'폴더블폰 대중화' 본격 시동
# 149              역시 삼성전자, 국내 최대 사회복지사업 450억원 규모
#
#                                                     링크  \
# 0    https://finance.naver.com/item/news_read.nhn?a...
# 1    https://finance.naver.com/item/news_read.nhn?a...
# 2    https://finance.naver.com/item/news_read.nhn?a...
# 3    https://finance.naver.com/item/news_read.nhn?a...
# 4    https://finance.naver.com/item/news_read.nhn?a...
# ...

# %% [markdown]
# # 단어의 등장빈도수 파악

# %%
import numpy as np

# %%
tokenized_news = np.hstack(loaded_df['tokenized'].values) # 하나의 리스트로 변환

# %%
print(tokenized_news)
# Out:
# ['삼성' '전자' '캐나다' ... '개' '기관' '예정']

# %%
len(tokenized_news)
# Out:
# 45700

# %%
from collections import Counter # 단어 등장 빈도 카운드 함수

# %%
test_list = ['바나나', '바나나', '바나나', '사과', '사과', '딸기', '메론', '수박', '수박', '토마토', '토마토', '전화기', '전화기', '전화기', '전화기']

# %%
test_word_count = Counter(test_list)
print(test_word_count)
print(test_word_count.most_common(3))
# Out:
# Counter({'전화기': 4, '바나나': 3, '사과': 2, '수박': 2, '토마토': 2, '딸기': 1, '메론': 1})
# [('전화기', 4), ('바나나', 3), ('사과', 2)]

# %%
news_word_count = Counter(tokenized_news)
print(news_word_count.most_common(20))
# Out:
# [('전자', 979), ('삼성', 783), ('등', 602), ('것', 492), ('기업', 431), ('반도체', 351), ('사업', 323), ('개', 301), ('수', 298), ('이', 298), ('투자', 293), ('생산', 270), ('부문', 238), ('시장', 227), ('미국', 218), ('위', 216), ('갤럭시', 205), ('올해', 201), ('올림픽', 199), ('를', 191)]

# %% [markdown]
# # 워드 클라우드

# %%
loaded_df.tokenized.reset_index(drop=True)
# Out:
# 0      [삼성, 전자, 캐나다, 법인, 이번, 도쿄, 올림픽, 캐나다, 선수, 메달, 딸,...
# 1      [지난, 오후, 일본, 도쿄, 국립경기장, 도쿄올림픽, 개막식, 성화, 대가, 사진...
# 2      [삼성, 전자, 글로벌, 뉴스룸, 삼성, 전자, 글로벌, 뉴스룸, 삼성, 전자, 일...
# 3      [삼성, 전자, 도쿄올림픽, 캐나다, 선수, 올림픽, 메달, 딸, 때, 기부, 사진...
# 4      [소재, 부품, 장비, 주가, 상승, 반도체, 올해, 쑥, 메모리, 반도체, 부동,...
#                              ...
# 145    [육성, 공정, 거래, 위원회, 기업, 집단, 국장, 지난, 정부, 세종, 청사, ...
# 146    [과학, 강국, 위해, 출연, 기초과학, 소재, 지원, 스타트업, 요람, 랩, 운영...
# 147    [샤오미, 삼성, 점유, 율, 포인트, 차, 애플, 아이폰, 역대, 판매량, 예고,...
# 148    [이데일리, 빅머, 부, 기업, 이슈, 방송, 이데일리, 김종호, 기자, 이데일리,...
# 149    [국내, 최대, 사회, 복지, 사업, 나눔, 꿈, 로고, 국내, 최대, 사회, 복지...
# Name: tokenized, Length: 150, dtype: object

# %%
temp_data = ' '.join(np.concatenate(loaded_df.tokenized.reset_index(drop=True)))
# 모든 단어에 대해서 띄어쓰기 기준으로 구분한 상태로 전처리

# %%
temp_data
# Out:
# '삼성 전자 캐나다 법인 이번 도쿄 올림픽 캐나다 선수 메달 딸 때 기부 삼성 전자 글로벌 뉴스룸 삼성 전자 캐나다 법인 캐나다 국가대표 선수 메달 획득 때 캐나다 올림픽 재단 기부 계획 기부 금액 캐나다 스포츠 교육 프로그램 지원 등 스포츠 발전 위해 사용 도쿄 올림픽 글로벌 파트너 사인 전자 올해 캐나다 선수 목표 최대 개 메달 달성 위해 최대 지원 금액 약속 바 제프 조 삼성 전자 캐나다 법인 다음 세대 선수 횃불 전달 위해 더 노력 며 캐나다 선수 도쿄 성공 경기 응원 고 말 데이비드 슈 메이커 캐나다 올림픽 위원회 사무 총장 캐나다 선수 스포츠 프로그램 지원 전자 결정 매우 며 올해 올림픽 예년 선수 지원 힘 것 말 전자 서울 올림픽 지역 파트너 시작 일본 나가노 동계 올림픽 글로벌 파트너 사 참여 이번 도쿄 올림픽 무선통신 분야 공식 파트너 사 활동 선수단 전원 최신 스마트폰 갤럭시 도쿄 올림픽 에디 션 제공 지난 오후 일본 도쿄 국립경기장 도쿄올림픽 개막식 성화 대가 사진 뉴스 지난 오후 일본 도쿄 국립경기장 도쿄올림픽 개막식 성화 대가 사진 뉴스 사진 삼성 전자 글로벌 뉴스룸 홈페이지 캡처 사진 삼성 전자 글로벌 뉴스룸 홈페이지 캡처 삼성 전자 캐나다 법인 도쿄올림픽 캐나다 선수 메달 딸 때 약 기부 삼성 전자 글로벌 뉴스룸 삼성 전자 캐나다 법인 스포츠 시스템 발전 위해 캐나다 선수 도쿄올림픽 메달 획득 때 기부 전자 캐나다 올림픽 위원회 파트너 지역 사회 수준 스포츠 프로그램 운동선수 지망 생 위 교육 자금 지원 총 최대 개 메달 를 기부 계획 제프 조 삼성 전자 캐나다 법인 최고경영자 다음 세대 캐나다 선수 성화 전달 위 더 며 캐나다 선수 도쿄 성공 경기 고 말 데이비드 슈 메이커 캐나다 올림픽 위원회 사무 총장 전자 캐나다 대표팀 지원 결정 것 생각 며 올해 올림픽 예년 수 선수 상대 과정 이 지원 힘 것 전자 국내 올림픽 글로벌 파트너 서울 올림픽 지역 파트너 시작 동계 올림픽 글로벌 파트너 참여 미국 로스앤젤레스 하계올림픽 후원 
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
import matplotlib.font_manager as fm
font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
font_list[:]
# Out:
# ['C:\\Users\\qazpl\\AppData\\Local\\Microsoft\\Windows\\Fonts\\SCDream3.otf',
#  'C:\\Windows\\Fonts\\georgiai.ttf',
#  'C:\\Windows\\Fonts\\BOD_R.TTF',
#  'C:\\WINDOWS\\Fonts\\Nirmala.ttf',
#  'C:\\WINDOWS\\Fonts\\avncyrli.ttf',
#  'C:\\Windows\\Fonts\\TEMPSITC.TTF',
#  'C:\\Windows\\Fonts\\LFAX.TTF',
#  'C:\\WINDOWS\\Fonts\\ERASMD.TTF',
#  'C:\\WINDOWS\\Fonts\\YuGothL.ttc',
#  'C:\\Windows\\Fonts\\avncyrdi.ttf',
#  'C:\\WINDOWS\\Fonts\\DUBAI-BOLD.TTF',
#  'C:\\WINDOWS\\Fonts\\BOOKOSB.TTF',
#  'C:\\Windows\\Fonts\\ROCCB___.TTF',
#  'C:\\WINDOWS\\Fonts\\COPRGTL.TTF',
#  'C:\\WINDOWS\\Fonts\\NirmalaS.ttf',
#  'C:\\Windows\\Fonts\\BOOKOS.TTF',
#  'C:\\WINDOWS\\Fonts\\LTYPEB.TTF',
#  'C:\\WINDOWS\\Fonts\\COPRGTB.TTF',
#  'C:\\Windows\\Fonts\\avncyrl.ttf',
#  'C:\\Windows\\Fonts\\avnltr.ttf',
#  'C:\\WINDOWS\\Fonts\\ITCBLKAD.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_PSTC.TTF',
#  'C:\\WINDOWS\\Fonts\\TCMI____.TTF',
#  'C:\\WINDOWS\\Fonts\\cambriaz.ttf',
#  'C:\\WINDOWS\\Fonts\\sylfaen.ttf',
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager
font_fname = 'C:\\Users\\qazpl\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothic.ttf'
font_family = font_manager.FontProperties(fname=font_fname).get_name()
plt.rcParams["font.family"] = font_family

# %%
# 뉴스 기사의 워드클라우드
plt.figure(figsize = (15,15))
temp_data = ' '.join(np.concatenate(loaded_df.tokenized.reset_index(drop=True)))
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800, font_path = font_fname).generate(temp_data)
plt.imshow(wc, interpolation = 'bilinear')

# %% [markdown]
# https://wikidocs.net/22530
# ->불용어 제거
